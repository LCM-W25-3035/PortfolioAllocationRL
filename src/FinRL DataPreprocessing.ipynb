# %%
# Importing the libraries
import pandas as pd
import numpy as np

# %%
# read and load the dataset
df = pd.read_csv("C:/Users/nikhi/Downloads/Final_Merged_Ticker_data.csv")
print(df.head(5))
# Out:
# C:\Users\nikhi\AppData\Local\Temp\ipykernel_39700\515789089.py:2: DtypeWarning: Columns (8,9,10,35,44,59,94,95) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("C:/Users/nikhi/Downloads/Final_Merged_Ticker_data.csv")
#          date  close   high    low   open  volume     tic  day  \
# 0  2004-01-01  0.105  0.105  0.105  0.105       0  DYA.TO    3
# 1  2004-01-02  0.105  0.105  0.105  0.105       0  DYA.TO    4
# 2  2004-01-05  0.105  0.105  0.105  0.105       0  DYA.TO    0
# 3  2004-01-06  0.105  0.105  0.105  0.105       0  DYA.TO    1
# 4  2004-01-07  0.105  0.105  0.105  0.105       0  DYA.TO    2
#
#                          industry       sector  ... earningsGrowth  \
# 0  Specialty Industrial Machinery  Industrials  ...            NaN
# 1  Specialty Industrial Machinery  Industrials  ...            NaN
# 2  Specialty Industrial Machinery  Industrials  ...            NaN
# ...

# %%
#Dataset shape
df.shape
# Out:
# (4059430, 100)

# %%
df.columns
# Out:
# Index(['date', 'close', 'high', 'low', 'open', 'volume', 'tic', 'day',
#        'industry', 'sector', 'longBusinessSummary', 'priceHint', 'beta',
#        'regularMarketVolume', 'averageVolume', 'marketCap', 'fiftyTwoWeekLow',
#        'fiftyTwoWeekHigh', 'priceToSalesTrailing12Months', 'fiftyDayAverage',
#        'twoHundredDayAverage', 'currency', 'enterpriseValue', 'floatShares',
#        'sharesOutstanding', 'sharesShort', 'sharesShortPriorMonth',
#        'sharesPercentSharesOut', 'heldPercentInsiders', 'shortRatio',
#        'impliedSharesOutstanding', 'bookValue', 'priceToBook',
#        'netIncomeToCommon', 'trailingEps', 'lastSplitFactor',
#        'enterpriseToRevenue', '52WeekChange', 'SandP52WeekChange',
#        'lastDividendValue', 'quoteType', 'symbol', 'shortName', 'longName',
#        'recommendationKey', 'totalCash', 'totalCashPerShare', 'totalDebt',
#        'quickRatio', 'currentRatio', 'totalRevenue', 'debtToEquity',
# ...

# %%
#data types
df.dtypes
# Out:
# date                       object
# close                     float64
# high                      float64
# low                       float64
# open                      float64
#                            ...
# legalType                  object
# yield                     float64
# threeYearAverageReturn    float64
# fiveYearAverageReturn     float64
# beta3Year                 float64
# Length: 100, dtype: object

# %%
# Statistics of the dataset
df.describe()
# Out:
# c:\Users\nikhi\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# c:\Users\nikhi\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
#               close          high           low          open        volume  \
# count  4.059430e+06  4.059430e+06  4.059430e+06  4.059430e+06  4.059430e+06
# mean   4.160183e+04  4.292181e+04  4.036108e+04  4.178175e+04  2.569096e+05
# std    5.612506e+06  5.770054e+06  5.463705e+06  5.630699e+06  9.665778e+05
# min    5.000000e-03  5.000000e-03  5.000000e-03  5.000000e-03  0.000000e+00
# 25%    3.874592e+00  3.942122e+00  3.801170e+00  3.880000e+00  1.600000e+03
# 50%    1.241807e+01  1.250940e+01  1.231936e+01  1.242094e+01  1.536100e+04
# ...

# %%
# Missing values
df.isnull().sum()
# Out:
# date                            0
# close                           0
# high                            0
# low                             0
# open                            0
#                            ...
# legalType                 2465508
# yield                     2717777
# threeYearAverageReturn    2566355
# fiveYearAverageReturn     2744330
# beta3Year                 2716555
# Length: 100, dtype: int64

# %%
# Calculate missing values and their percentages
missing_values = df.isnull().sum()
missing_percentage = (missing_values / len(df)) * 100

print(missing_percentage[missing_percentage > 0])
# Out:
# industry                  40.093757
# sector                    40.093757
# longBusinessSummary       40.004065
# beta                      45.292492
# marketCap                 39.480026
#                             ...
# legalType                 60.735325
# yield                     66.949720
# threeYearAverageReturn    63.219590
# fiveYearAverageReturn     67.603826
# beta3Year                 66.919617
# Length: 81, dtype: float64

# %%
# Drop columns with more than 50% missing values
threshold = 50  # Percentage threshold
columns_to_drop = missing_percentage[missing_percentage > threshold].index
df = df.drop(columns=columns_to_drop)

print(f"Dropped columns: {columns_to_drop.tolist()}")
# Out:
# Dropped columns: ['lastSplitFactor', 'enterpriseToRevenue', 'lastDividendValue', 'trailingPegRatio', 'profitMargins', 'forwardEps', 'targetHighPrice', 'targetLowPrice', 'targetMeanPrice', 'targetMedianPrice', 'recommendationMean', 'numberOfAnalystOpinions', 'revenueGrowth', 'grossMargins', 'ebitdaMargins', 'auditRisk', 'boardRisk', 'compensationRisk', 'shareHolderRightsRisk', 'overallRisk', 'fiveYearAvgDividendYield', 'shortPercentOfFloat', 'dividendRate', 'dividendYield', 'payoutRatio', 'trailingAnnualDividendRate', 'trailingAnnualDividendYield', 'earningsQuarterlyGrowth', 'earningsGrowth', 'totalAssets', 'navPrice', 'ytdReturn', 'fundFamily', 'legalType', 'yield', 'threeYearAverageReturn', 'fiveYearAverageReturn', 'beta3Year']

# %%
df.shape
# Out:
# (4059430, 62)

# %%
print(df.isnull().sum())
# Out:
# date                             0
# close                            0
# high                             0
# low                              0
# open                             0
#                             ...
# forwardPE                  2010043
# heldPercentInstitutions    1904360
# enterpriseToEbitda         1981825
# ebitda                     1889390
# trailingPE                 1723966
# Length: 62, dtype: int64

# %%
# Check for rows with missing values
rows_with_missing = df.isnull().any(axis=1).sum()
print(f"{rows_with_missing}")
# Out:
# 3108994

# %%
missing_values = df.isnull().sum()
print(missing_values[missing_values > 0])
# Out:
# industry                        1627578
# sector                          1627578
# longBusinessSummary             1623937
# beta                            1838617
# marketCap                       1602664
# priceToSalesTrailing12Months    1986236
# enterpriseValue                 1746368
# floatShares                     1723711
# sharesOutstanding               1623630
# sharesShort                     1629384
# sharesShortPriorMonth           1629392
# sharesPercentSharesOut          1855587
# heldPercentInsiders             1706272
# shortRatio                      1661626
# impliedSharesOutstanding        1634780
# bookValue                       1657504
# priceToBook                     1793855
# netIncomeToCommon               1646951
# trailingEps                     1689709
# 52WeekChange                    1664047
# SandP52WeekChange               1622306
# longName                           3296
# recommendationKey               1601566
# ...

# %%
df['industry'] = df['industry'].fillna('Unknown')
