# %%
# !pip install git+https://github.com/AI4Finance-Foundation/FinRL.git
# Out:
# ...
#   Cloning https://github.com/AI4Finance-Foundation/FinRL.git to /tmp/pip-req-build-ul94tuco
#   Running command git clone --filter=blob:none --quiet https://github.com/AI4Finance-Foundation/FinRL.git /tmp/pip-req-build-ul94tuco
#   Resolved https://github.com/AI4Finance-Foundation/FinRL.git to commit 3a10805389c07e13e94333e94dcfe9beafce49b0
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Cloning https://github.com/AI4Finance-Foundation/ElegantRL.git to /tmp/pip-install-dph1zozd/elegantrl_052745fabfea4177b1deb9da15e7b7cc
#   Running command git clone --filter=blob:none --quiet https://github.com/AI4Finance-Foundation/ElegantRL.git /tmp/pip-install-dph1zozd/elegantrl_052745fabfea4177b1deb9da15e7b7cc
#   Resolved https://github.com/AI4Finance-Foundation/ElegantRL.git to commit 62bf617fa87cf82b9fbf88307715d93b8ab8ee80
#   Preparing metadata (setup.py) ... done
# ...

# %%
# !pip install quantstats
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.8/45.8 kB 2.4 MB/s eta 0:00:00
# ...

# %%
from finrl.meta.env_portfolio_allocation.env_portfolio import StockPortfolioEnv
from finrl import config
from finrl import config_tickers
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_portfolio_allocation.env_portfolio import StockPortfolioEnv
from finrl.agents.stablebaselines3.models import DRLAgent
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline,convert_daily_return_to_pyfolio_ts
from finrl.meta.data_processor import DataProcessor
from finrl.meta.data_processors.processor_yahoofinance import YahooFinanceProcessor
import sys
sys.path.append("../FinRL-Library")
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
import pandas as pd
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
import os
if not os.path.exists("./" + config.DATA_SAVE_DIR):
    os.makedirs("./" + config.DATA_SAVE_DIR)
if not os.path.exists("./" + config.TRAINED_MODEL_DIR):
    os.makedirs("./" + config.TRAINED_MODEL_DIR)
if not os.path.exists("./" + config.TENSORBOARD_LOG_DIR):
    os.makedirs("./" + config.TENSORBOARD_LOG_DIR)
if not os.path.exists("./" + config.RESULTS_DIR):
    os.makedirs("./" + config.RESULTS_DIR)

# %%
df_portfolio = pd.read_csv("TSX Chart Data Sorted By Date.csv")
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df_portfolio.shape
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (1048575, 8)

# %%
df_portfolio.head(20)
# Out:
#           date        close      high       low      open  volume     tic  day
# 0   2004-01-01     0.105000     0.105     0.105     0.105       0  DYA.TO    3
# 1   2004-01-01     1.378000     2.650     2.650     2.650       0  EDT.TO    3
# 2   2004-01-02     0.489625     0.530     0.530     0.530       0  AAB.TO    4
# 3   2004-01-02    22.070272    29.850    29.320    29.430  413000  ABX.TO    4
# 4   2004-01-02     3.484277     7.050     7.050     7.050     100  ACD.TO    4
# 5   2004-01-02     8.834254    13.580    13.160    13.160    8671  ACX.TO    4
# 6   2004-01-02    12.162339    15.830    15.500    15.500   42500  AEM.TO    4
# 7   2004-01-02     0.762091     0.770     0.770     0.770       0   AG.TO    4
# 8   2004-01-02     2.261605     2.750     2.560     2.750   24800  AGI.TO    4
# 9   2004-01-02     2.612467     6.200     6.200     6.200    1000  ALC.TO    4
# 10  2004-01-02     2.121329     2.500     2.330     2.330  176300  ALS.TO    4
# ...

# %%
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split

# %%
fe = FeatureEngineer()
df = fe.preprocess_data(df_portfolio)
df = df_portfolio
# Out:
# Successfully added technical indicators

# %%
df.shape
# Out:
# (1048575, 8)

# %%
df.tic.unique()
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# array(['DYA.TO', 'EDT.TO', 'AAB.TO', 'ABX.TO', 'ACD.TO', 'ACX.TO',
#        'AEM.TO', 'AG.TO', 'AGI.TO', 'ALC.TO', 'ALS.TO', 'AMM.TO',
#        'AOI.TO', 'AOT.TO', 'APS.TO', 'AQN.TO', 'ARE.TO', 'ARG.TO',
#        'ARX.TO', 'ASM.TO', 'ATCU.TO', 'ATD.TO', 'ATRL.TO', 'ATS.TO',
#        'AVL.TO', 'BB.TO', 'BCE.TO', 'BDGI.TO', 'BDT.TO', 'BHC.TO',
#        'BIR.TO', 'BLDP.TO', 'BLX.TO', 'BMO.TO', 'BN.TO', 'BNE.TO',
#        'BNG.TO', 'BNS.TO', 'BOS.TO', 'BR.TO', 'BRY.TO', 'BSX.TO',
#        'BTE.TO', 'BU.TO', 'BUI.TO', 'BYD.TO', 'CAE.TO', 'CAS.TO',
#        'CCA.TO', 'CCM.TO', 'CCO.TO', 'CFP.TO', 'CFW.TO', 'CGG.TO',
# ...

# %%
df.head(20)
# Out:
#           date        close      high       low      open  volume     tic  day
# 0   2004-01-01     0.105000     0.105     0.105     0.105       0  DYA.TO    3
# 1   2004-01-01     1.378000     2.650     2.650     2.650       0  EDT.TO    3
# 2   2004-01-02     0.489625     0.530     0.530     0.530       0  AAB.TO    4
# 3   2004-01-02    22.070272    29.850    29.320    29.430  413000  ABX.TO    4
# 4   2004-01-02     3.484277     7.050     7.050     7.050     100  ACD.TO    4
# 5   2004-01-02     8.834254    13.580    13.160    13.160    8671  ACX.TO    4
# 6   2004-01-02    12.162339    15.830    15.500    15.500   42500  AEM.TO    4
# 7   2004-01-02     0.762091     0.770     0.770     0.770       0   AG.TO    4
# 8   2004-01-02     2.261605     2.750     2.560     2.750   24800  AGI.TO    4
# 9   2004-01-02     2.612467     6.200     6.200     6.200    1000  ALC.TO    4
# 10  2004-01-02     2.121329     2.500     2.330     2.330  176300  ALS.TO    4
# ...

# %%
# add covariance matrix as states
df=df.sort_values(['date','tic'],ignore_index=True)
df.index = df.date.factorize()[0]

cov_list = []
return_list = []

# look back is one year
lookback=252
for i in range(lookback,len(df.index.unique())):
  data_lookback = df.loc[i-lookback:i,:]
  price_lookback=data_lookback.pivot_table(index = 'date',columns = 'tic', values = 'close')
  return_lookback = price_lookback.pct_change().dropna()
  return_list.append(return_lookback)

  covs = return_lookback.cov().values
  cov_list.append(covs)


df_cov = pd.DataFrame({'date':df.date.unique()[lookback:],'cov_list':cov_list,'return_list':return_list})
df = df.merge(df_cov, on='date')
df = df.sort_values(['date','tic']).reset_index(drop=True)
# Out:
# Streaming output truncated to the last 5000 lines.
# /usr/local/lib/python3.11/dist-packages/numpy/lib/function_base.py:520: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# /usr/local/lib/python3.11/dist-packages/numpy/core/_methods.py:121: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py:11211: RuntimeWarning: Degrees of freedom <= 0 for slice
#   base_cov = np.cov(mat.T, ddof=ddof)
# /usr/local/lib/python3.11/dist-packages/numpy/lib/function_base.py:2748: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.11/dist-packages/numpy/lib/function_base.py:2748: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# ...

# %%
df.shape
# Out:
# (1026079, 10)

# %%
df.head()
# Out:
#          date      close       high        low       open  volume     tic  \
# 0  2004-12-20   0.415720   0.450000   0.450000   0.450000       0  AAB.TO
# 1  2004-12-20  21.684490  29.090000  28.629999  28.629999  892100  ABX.TO
# 2  2004-12-20   4.109743   8.100000   8.100000   8.100000    1000  ACD.TO
# 3  2004-12-20  17.205807  24.150000  23.100000  23.799999   22143  ACX.TO
# 4  2004-12-20  12.918009  17.040001  16.670000  16.790001  217000  AEM.TO
#
#    day                                           cov_list  \
# 0    0  [[0.009335785113573457, -0.0001770641735861586...
# 1    0  [[0.009335785113573457, -0.0001770641735861586...
# 2    0  [[0.009335785113573457, -0.0001770641735861586...
# 3    0  [[0.009335785113573457, -0.0001770641735861586...
# 4    0  [[0.009335785113573457, -0.0001770641735861586...
#
#                                          return_list
# 0  tic           AAB.TO    ABX.TO    ACD.TO    AC...
# 1  tic           AAB.TO    ABX.TO    ACD.TO    AC...
# ...

# %%
df.tail()
# Out:
#                date    close        high          low        open  volume  \
# 1026074  2024-12-27    21.60    21.65000    21.219999    21.40000  153600
# 1026075  2024-12-27     0.37     0.38000     0.360000     0.36000   16900
# 1026076  2024-12-27  1311.25  1319.98999  1299.520020  1299.52002    1200
# 1026077  2024-12-27     0.85     0.88000     0.840000     0.88000  116800
# 1026078  2024-12-27     0.15     0.15000     0.150000     0.15000    4500
#
#              tic  day                                           cov_list  \
# 1026074   ELD.TO    4  [[0.014899914608964001, 0.001120277539557747, ...
# 1026075  ELEF.TO    4  [[0.014899914608964001, 0.001120277539557747, ...
# 1026076   ELF.TO    4  [[0.014899914608964001, 0.001120277539557747, ...
# 1026077   ELO.TO    4  [[0.014899914608964001, 0.001120277539557747, ...
# 1026078   ELR.TO    4  [[0.014899914608964001, 0.001120277539557747, ...
#
#                                                return_list
# ...

# %%
train = data_split(df, '2004-01-01','2008-12-31')

# %%
train.head()
# Out:
#          date      close       high        low       open  volume     tic  \
# 0  2004-12-20   0.415720   0.450000   0.450000   0.450000       0  AAB.TO
# 0  2004-12-20  21.684490  29.090000  28.629999  28.629999  892100  ABX.TO
# 0  2004-12-20   4.109743   8.100000   8.100000   8.100000    1000  ACD.TO
# 0  2004-12-20  17.205807  24.150000  23.100000  23.799999   22143  ACX.TO
# 0  2004-12-20  12.918009  17.040001  16.670000  16.790001  217000  AEM.TO
#
#    day                                           cov_list  \
# 0    0  [[0.009335785113573457, -0.0001770641735861586...
# 0    0  [[0.009335785113573457, -0.0001770641735861586...
# 0    0  [[0.009335785113573457, -0.0001770641735861586...
# 0    0  [[0.009335785113573457, -0.0001770641735861586...
# 0    0  [[0.009335785113573457, -0.0001770641735861586...
#
#                                          return_list
# 0  tic           AAB.TO    ABX.TO    ACD.TO    AC...
# 0  tic           AAB.TO    ABX.TO    ACD.TO    AC...
# ...

# %%
train.tail()
# Out:
#             date       close   high     low    open  volume      tic  day  \
# 1014  2008-12-30  260.000000  270.0  260.00  270.00      50  ELEF.TO    1
# 1014  2008-12-30  284.767181  425.0  425.00  425.00     200   ELF.TO    1
# 1014  2008-12-30    2.800000    2.8    2.40    2.40     275   ELO.TO    1
# 1014  2008-12-30    3.500000    3.7    3.30    3.60  245130   ELR.TO    1
# 1014  2008-12-30    1.200000    1.3    1.15    1.15    4800  ELVA.TO    1
#
#                                                cov_list  \
# 1014  [[0.0063487681552264075, 0.0007747908218029484...
# 1014  [[0.0063487681552264075, 0.0007747908218029484...
# 1014  [[0.0063487681552264075, 0.0007747908218029484...
# 1014  [[0.0063487681552264075, 0.0007747908218029484...
# 1014  [[0.0063487681552264075, 0.0007747908218029484...
#
#                                             return_list
# 1014  tic           AAB.TO    ABX.TO    ACD.TO    AC...
# 1014  tic           AAB.TO    ABX.TO    ACD.TO    AC...
# ...

# %%
stock_dimension = len(train.tic.unique())
state_space = stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 132, State Space: 132

# %%
from finrl import config

# %%
train
# Out:
#             date       close        high         low        open  volume  \
# 0     2004-12-20    0.415720    0.450000    0.450000    0.450000       0
# 0     2004-12-20   21.684490   29.090000   28.629999   28.629999  892100
# 0     2004-12-20    4.109743    8.100000    8.100000    8.100000    1000
# 0     2004-12-20   17.205807   24.150000   23.100000   23.799999   22143
# 0     2004-12-20   12.918009   17.040001   16.670000   16.790001  217000
# ...          ...         ...         ...         ...         ...     ...
# 1014  2008-12-30  260.000000  270.000000  260.000000  270.000000      50
# 1014  2008-12-30  284.767181  425.000000  425.000000  425.000000     200
# 1014  2008-12-30    2.800000    2.800000    2.400000    2.400000     275
# 1014  2008-12-30    3.500000    3.700000    3.300000    3.600000  245130
# 1014  2008-12-30    1.200000    1.300000    1.150000    1.150000    4800
#
#           tic  day                                           cov_list  \
# ...

# %%
df["cov_list"].values[10]
# Out:
# array([[ 9.33578511e-03, -1.77064174e-04, -2.41722955e-04, ...,
#          1.09106765e-04, -9.57817708e-05, -4.40586243e-04],
#        [-1.77064174e-04,  2.18624177e-04,  9.41348069e-07, ...,
#         -1.08353227e-05,  7.11334593e-05,  7.16566591e-05],
#        [-2.41722955e-04,  9.41348069e-07,  7.88279562e-04, ...,
#         -7.05087166e-06,  4.26553707e-05, -1.78650959e-04],
#        ...,
#        [ 1.09106765e-04, -1.08353227e-05, -7.05087166e-06, ...,
#          2.21115191e-04, -1.91547895e-04,  2.05752034e-06],
#        [-9.57817708e-05,  7.11334593e-05,  4.26553707e-05, ...,
#         -1.91547895e-04,  3.95109288e-03,  1.99793837e-04],
#        [-4.40586243e-04,  7.16566591e-05, -1.78650959e-04, ...,
#          2.05752034e-06,  1.99793837e-04,  3.16168905e-03]])

# %%
env_kwargs = {
    "hmax": 100,
    "initial_amount": 1000000,
    "transaction_cost_pct": 0.001,
    "state_space": 10,
    "stock_dim": stock_dimension,
    "tech_indicator_list": [],
    "action_space": stock_dimension,
    "reward_scaling": 1e-4

}

e_train_gym = StockPortfolioEnv(df = train, **env_kwargs)
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-158-d4d42d6a7c28> in <cell line: 0>()
#      11 }
#      12
# ---> 13 e_train_gym = StockPortfolioEnv(df = train, **env_kwargs)
#
# /usr/local/lib/python3.11/dist-packages/finrl/meta/env_portfolio_allocation/env_portfolio.py in __init__(self, df, stock_dim, hmax, initial_amount, transaction_cost_pct, reward_scaling, state_space, action_space, tech_indicator_list, turbulence_threshold, lookback, day)
#     106         self.data = self.df.loc[self.day, :]
# ...

# %%
from finrl.meta.data_processor import DataProcessor
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df_portfolio.head()
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#          date      close    high     low    open  volume     tic  day
# 0  2004-01-01   0.105000   0.105   0.105   0.105       0  DYA.TO    3
# 1  2004-01-01   1.378000   2.650   2.650   2.650       0  EDT.TO    3
# 2  2004-01-02   0.489625   0.530   0.530   0.530       0  AAB.TO    4
# 3  2004-01-02  22.070272  29.850  29.320  29.430  413000  ABX.TO    4
# 4  2004-01-02   3.484277   7.050   7.050   7.050     100  ACD.TO    4

# %%
dp = DataProcessor(df_portfolio)
rocessed_data = dp.clean_data()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-169-fbea1d61d799> in <cell line: 0>()
# ----> 1 dp = DataProcessor(df_portfolio)
#       2 processed_data = dp.clean_data()
#
# /usr/local/lib/python3.11/dist-packages/finrl/meta/data_processor.py in __init__(self, data_source, tech_indicator, vix, **kwargs)
#      13 class DataProcessor:
#      14     def __init__(self, data_source, tech_indicator=None, vix=None, **kwargs):
# ---> 15         if data_source == "alpaca":
#      16             try:
#      17                 API_KEY = kwargs.get("API_KEY")
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __nonzero__(self)
#    1575     @final
#    1576     def __nonzero__(self) -> NoReturn:
# -> 1577         raise ValueError(
#    1578             f"The truth value of a {type(self).__name__} is ambiguous. "
# ...

# %%
from stable_baselines3.common.vec_env import DummyVecEnv
from finrl.meta.env_portfolio_optimization.env_portfolio_optimization import PortfolioOptimizationEnv

# %%
tickers_list = df_portfolio.tic.unique()
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
pip install 'shimmy>=2.0'

# %%
env_kwargs = {
    "df": df_portfolio,
    "initial_amount": 1e6,  # Initial capital
    "comission_fee_pct": 0.001,  # Trading cost
    "reward_scaling": 1e-4,
    "time_window": 50,
    "normalize_df": None
}

env = PortfolioOptimizationEnv(**env_kwargs)
env = DummyVecEnv([lambda: env])  # Vectorized for SB3 compatibility
# Out:
# /usr/local/lib/python3.11/dist-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(

# %%
from stable_baselines3 import A2C

# %%
model = A2C("MlpPolicy", env, verbose=1, learning_rate=0.0005, gamma=0.99)
model.learn(total_timesteps=100000)
# Out:
# Using cpu device
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-186-e893f55cb1c8> in <cell line: 0>()
#       1 model = A2C("MlpPolicy", env, verbose=1, learning_rate=0.0005, gamma=0.99)
# ----> 2 model.learn(total_timesteps=100000)
#
# /usr/local/lib/python3.11/dist-packages/stable_baselines3/a2c/a2c.py in learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     199         progress_bar: bool = False,
#     200     ) -> SelfA2C:
# --> 201         return super().learn(
#     202             total_timesteps=total_timesteps,
#     203             callback=callback,
#
# /usr/local/lib/python3.11/dist-packages/stable_baselines3/common/on_policy_algorithm.py in learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     309         iteration = 0
#     310
# ...
